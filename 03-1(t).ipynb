# %%
import pandas as pd

# %%
df = pd.read_csv('data/Fish.csv')
df
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
cond = df['Species'] == 'Perch'
perch_data = df.loc[cond]
perch_data.head()
# Out:
#    Species  Weight  Length1  Length2  Length3  Height   Width
# 72   Perch     5.9      7.5      8.4      8.8  2.1120  1.4080
# 73   Perch    32.0     12.5     13.7     14.7  3.5280  1.9992
# 74   Perch    40.0     13.8     15.0     16.0  3.8240  2.4320
# 75   Perch    51.5     15.0     16.2     17.2  4.5924  2.6316
# 76   Perch    70.0     15.7     17.4     18.5  4.5880  2.9415

# %%
import matplotlib.pyplot as plt

plt.scatter(perch_data['Length2'], perch_data['Weight'])
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
train_input, test_input, train_target, test_target = train_test_split(
    perch_data[['Length2']], perch_data[['Weight']]
)

# %%
type(perch_data['Weight'])
# Out:
# pandas.core.series.Series

# %%
type(perch_data[['Weight']])
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knr = KNeighborsRegressor()

# %%
knr.fit(train_input, train_target)
# Out:
# KNeighborsRegressor()

# %%
knr.score(test_input, test_target)
# Out:
# 0.937067294530893

# %%
knr.score(train_input, train_target)
# Out:
# 0.9758771282156886

# %%
knr.n_neighbors = 3

# %%
knr.fit(train_input, train_target)
print(knr.score(train_input, train_target))
print(knr.score(test_input, test_target))
# Out:
# 0.9761492107397733
# 0.9478968089524922

# %%
knr.predict([[200]])
# Out:
# C:\Users\2-00\Desktop\DMF\ML\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# array([[940.]])
