# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('data/Fish.csv')

# %%
# from sklearn.neighbors import

# %%
from sklearn.model_selection import train_test_split

# %%
# cond = df['species'].isin(['Bream', 'Smelt'])
# lw_df = df.loc[cond, ['Length2', 'Weight']]
# fish_data = lw_df
# Out:
# -------------------------------------------------------------------
# KeyError                          Traceback (most recent call last)
# Cell In[273], line 2
#       1 cond = df['species'].isin(['Bream', 'Smelt'])
# ----> 2 lw_df = df.loc[cond, ['Length2', 'Weight']]
#       3 fish_data = lw_df
#
# File ~\Desktop\DMF\ML\venv\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\Desktop\DMF\ML\venv\Lib\site-packages\pandas\core\indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# -> 1377 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
cond
# Out:
# 0      True
# 1      True
# 2      True
# 4      True
# 5      True
#        ...
# 338    True
# 340    True
# 341    True
# 342    True
# 343    True
# Name: species, Length: 342, dtype: bool

# %%
# lw_df

# %%
fish_target = (pd.DataFrame([1] * 35 + [0] * 14))

# %%
# fish_data

# %%
X_train, X_test, y_train, y_test = train_test_split(fish_data, fish_target, test_size=0.25, stratify=fish_target)

# %%
np.array(dfx[0])
# Out:
# array([10.6, 31.5, 33.5, 25.4, 11.2, 26.5, 36. , 41. , 12.4, 31. , 35. ,
#        36. , 31. ])

# %%
from sklearn.neighbors import KNeighborsClassifier
kn = KNeighborsClassifier()

# %%
kn.fit(X_train, y_train)
# Out:
# C:\Users\이시운\Desktop\DMF\ML\venv\Lib\site-packages\sklearn\neighbors\_classification.py:238: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
kn.score(X_test, y_test)
# Out:
# 1.0

# %%
kn.predict([[10, 200]])
# Out:
# array([1])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(nfd[:,0],nfd[:,1])
plt.xlim(0,1500)
plt.ylim(0,1500)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dis, indexes = kn.kneighbors([[25,150]])

# %%
dfnn = fish_data.to_numpy()
# Out:
# -------------------------------------------------------------------
# AttributeError                    Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 dfnn = fish_data.to_numpy()
#
# AttributeError: 'list' object has no attribute 'to_numpy'

# %%
nfd = np.array(fish_data)

# %%
# fish_data

# %% [markdown]
# ## 표준점수
# - (데이터 - 평균) / 표준편차

# %%
dfx = pd.DataFrame(X_test)

# %%
mean = dfx.mean()

# %%
std = dfx.std()

# %%
tain_scaled = ((dfx - mean) / std).head()

# %%
# kn.fit(np.array(tain_scaled), y_train)

# %%
## 테스트 평균은 학습평균과 같은것을 써야 동일한 스케일이 적용되어 정확한 결과가 나옴

# %% [markdown]
# ## 펭귄 데이터 연습

# %%
import seaborn as sns

# %%
df = sns.load_dataset('penguins')

# %%
df.info().uniques()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB
# -------------------------------------------------------------------
# AttributeError                    Traceback (most recent call last)
# Cell In[359], line 1
# ----> 1 df.info().uniques()
#
# AttributeError: 'NoneType' object has no attribute 'uniques'

# %%
df['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
df.groupby(['species']).mean(numeric_only=True)
# Out:
#            bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# species
# Adelie          38.791391      18.346358         189.953642  3700.662252
# Chinstrap       48.833824      18.420588         195.823529  3733.088235
# Gentoo          47.504878      14.982114         217.186992  5076.016260

# %%
# Adelie, Gentoo : bill_length_mm, body_mass_g

# %%
df = df.dropna(subset=['bill_length_mm','bill_depth_mm', 'flipper_length_mm','body_mass_g'])

# %%
Adelie = df[df['species'] == 'Adelie']
Gentoo = df[df['species'] == 'Gentoo']

# %%
cond = df['species'].isin(['Adelie', 'Gentoo'])
ag_data = df.loc[cond, [ 'bill_length_mm','bill_depth_mm', 'flipper_length_mm','body_mass_g']]

# %%
arr_target = ['Adelie'] * len(Adelie) + ['Gentoo'] *len(Gentoo)

# %%
arr_tar = np.array(ag_target)

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split

# %%
st_da, te_da, st_ta, te_ta = train_test_split(ag_data, ag_target, test_size=0.25, stratify=ag_target)

# %%
st_da
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 289            50.7           15.0              223.0       5550.0
# 304            44.9           13.8              212.0       4750.0
# 139            39.7           17.9              193.0       4250.0
# 251            42.8           14.2              209.0       4700.0
# 322            47.2           15.5              215.0       4975.0
# ..              ...            ...                ...          ...
# 63             41.1           18.2              192.0       4050.0
# 263            49.6           15.0              216.0       4750.0
# 141            40.6           17.2              187.0       3475.0
# 273            50.1           15.0              225.0       5000.0
# 259            48.7           15.7              208.0       5350.0
#
# [205 rows x 4 columns]

# %%
# plt.scatter(st

# %%
kn.fit(st_da, st_ta)
# Out:
# KNeighborsClassifier()

# %%
kn.score(te_da, te_ta)
# Out:
# 0.8985507246376812

# %%
kn.score(te_da, te_ta)
# Out:
# 0.8985507246376812

# %%
st_scaled = (st_da - st_da.mean()) / st_da.std()

# %%
te_scaled = (te_da - st_da.mean()) / st_da.std()

# %%
kn.fit(st_scaled, st_ta)
# Out:
# KNeighborsClassifier()

# %%
kn.score(te_scaled, te_ta)
# Out:
# 1.0

# %%
distance, indexes = kn.kneighbors([[45, 4500]])
# Out:
# C:\Users\이시운\Desktop\DMF\ML\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
conda = (pd.DataFrame(st_ta) == 'Adelie')
condg = (pd.DataFrame(st_ta) == 'Gentoo')

# %%
plt.scatter(Adelie['bill_length_mm'], Adelie['body_mass_g'],marker='*')
plt.scatter(Gentoo['bill_length_mm'], Gentoo['body_mass_g'])

plt.xlabel('bill_length_mm')
plt.ylabel('body_mass_g')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(Adelie['bill_depth_mm'], Adelie['body_mass_g'])
plt.scatter(Gentoo['bill_depth_mm'], Gentoo['flipper_length_mm'])

# %%
# def agmark(x):
#     for xx in x:        
#         if xx == 'Adelie':
#             print( '*')
#         else:
#             print( 'o')



plt.scatter(st_da['bill_length_mm'], st_da['body_mass_g'])
plt.show()
